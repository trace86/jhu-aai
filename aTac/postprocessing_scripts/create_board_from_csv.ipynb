# %%
# create ascii tic tac toe board from csv output

# %%
import pandas as pd
import numpy as np
import ast

# %%
filename = "3x3_defender.csv"

df = pd.read_csv(filename, header=None)
df.columns = ["Previous State", "Next State", "Player", "Cyber Move", "Game ID"]

# %%
def printBoard(board):
    for i in range(len(board)):
        for j in range(len(board[i])):
            mark = ' '
            if board[i][j] == 1:
                mark = 'X'
            elif board[i][j] == 2:
                mark = 'O'
            if (j == len(board[i]) - 1):
                print(mark)
            else:
                print(str(mark) + "|", end='')
        if (i < len(board) - 1):
            if len(board) == 3:
                print("-----")
            else:
                print("----------")

# %%
def printBoard_from_history(df, game_id):
    game_df = df[df["Game ID"] == game_id]
    game_list = game_df["Next State"].to_list()
    player = game_df["Player"].to_list()
    cyber = game_df["Cyber Move"].to_list()

    print(f"Game ID: {game_id}")
    
    for i in range(len(game_list)):
        print("Player {0} move".format(player[i]))
        
        cyber_move = ast.literal_eval(cyber[i])
        
        if cyber_move:
            print("Cyber move: {0}".format(cyber_move[0]))
        else:
            print("Chaos Agent Activated")
        
        
        printBoard(ast.literal_eval(game_list[i]))
        print("")

# %%
# can probably add funcitonality to write to text file, but for now i've just been copy/pasting this output to a text file

for each in np.unique(df["Game ID"]):
    printBoard_from_history(df, game_id=each)
    print("-"*50)
    print("")
# Out:
# Game ID: 0887b24a-1047-448c-a56e-6e4c1ed3eb49
# Player 1 move
# Cyber move: scan_command
#  | |
# -----
# X| |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
# X|O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
# X|O|
# -----
#  |O|
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
# X|O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
# X|O|
# -----
#  |O|
#
# Player 2 move
# Cyber move: kill_daemon_command
# O| |
# -----
# X|O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: 0d245be0-0b09-4064-b26e-75fb1c58aea4
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O|X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|X|
# -----
#  |O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: 11319f1f-a90c-4950-94b3-19df53f70754
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  |X|
#
# Player 2 move
# Cyber move: nop_command
#  |X|O
# -----
#  |O|
# -----
#  |X|
#
# Player 1 move
# Chaos Agent Activated
#  |X|O
# -----
#  |O|
# -----
#  |X|
#
# Player 2 move
# Cyber move: kill_daemon_command
#  |X|O
# -----
#  |O|
# -----
# O|X|
#
# --------------------------------------------------
#
# Game ID: 209575a1-1730-4d55-87d0-89e9e915b603
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# X|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
#  |O|
# -----
# X| |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|
# -----
# X| |
#
# Player 1 move
# Cyber move: use_command
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 2 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X| |O
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|X|O
#
# --------------------------------------------------
#
# Game ID: 35f1ff50-a087-40aa-8aba-2cbb0cebe1a1
# Player 1 move
# Chaos Agent Activated
#  |O|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  |O|
# -----
#  |O|
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |O
#
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  |O|
# -----
#  |O|O
#
# Player 2 move
# Cyber move: kill_daemon_command
# O| |
# -----
#  |O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: 429e52b3-662e-47a6-905d-414483893ba4
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  | |
# -----
#  | |O
#
# Player 1 move
# Cyber move: scan_command
#  |X|X
# -----
#  | |
# -----
#  | |O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|X
# -----
#  | |
# -----
#  | |O
#
# Player 1 move
# Cyber move: nop_command
# O|X|X
# -----
#  | |
# -----
#  |X|O
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|X|X
# -----
#  |O|
# -----
#  |X|O
#
# --------------------------------------------------
#
# Game ID: 4327b84a-1ab1-4a31-ba45-c01fea3c2c7c
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|O
# -----
#  | |
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
#  |X|O
# -----
#  | |
# -----
# X| |
#
# Player 2 move
# Cyber move: nop_command
#  |X|O
# -----
#  | |
# -----
# X| |O
#
# Player 1 move
# Cyber move: scan_command
#  |X|O
# -----
#  | |
# -----
# X|X|O
#
# Player 2 move
# Cyber move: kill_daemon_command
#  |X|O
# -----
#  | |O
# -----
# X|X|O
#
# --------------------------------------------------
#
# Game ID: 53da06ef-e9c0-4827-9e29-75b657a63519
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  |O|
#
# Player 2 move
# Cyber move: kill_daemon_command
# O| |
# -----
#  |O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: 5b2534fc-6adf-4d26-8000-ea7ce512f191
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  |X|
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  |X|O
#
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  |O|X
# -----
#  |X|O
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|X|
# -----
#  |O|X
# -----
#  |X|O
#
# --------------------------------------------------
#
# Game ID: 677e7461-286a-42a8-b8a8-852ac98969c4
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: use_command
# X|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
#  |O|
# -----
# X| |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|
# -----
# X| |
#
# Player 1 move
# Cyber move: scan_command
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 2 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|O|
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|O|X
#
# --------------------------------------------------
#
# Game ID: 7f4cf299-1d98-4d27-9d3b-eef7e0300e72
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  | |
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# O| |
# -----
#  |X|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  |X|
# -----
#  | |O
#
# Player 1 move
# Cyber move: use_command
# O|X|
# -----
#  |X|
# -----
#  | |O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|
# -----
#  |X|
# -----
#  |O|O
#
# Player 1 move
# Cyber move: use_command
# O|X|
# -----
#  |X|
# -----
# X|O|O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|O
# -----
#  |X|
# -----
# X|O|O
#
# Player 1 move
# Cyber move: use_command
# O|X|O
# -----
#  |X|X
# -----
# X|O|O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|O
# -----
# O|X|X
# -----
# X|O|O
#
# --------------------------------------------------
#
# Game ID: 84c261ee-de63-4067-8cdc-5e788dbf3c6d
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
#  | |O
# -----
#  |O|
# -----
# O| |
#
# Player 2 move
# Cyber move: kill_daemon_command
#  | |O
# -----
#  |O|
# -----
# O| |
#
# --------------------------------------------------
#
# Game ID: 87d47d5f-234a-4584-8f8c-4b6954f32642
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# X|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
#  |O|
# -----
# X| |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|
# -----
# X| |
#
# Player 1 move
# Cyber move: use_command
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 2 move
# Chaos Agent Activated
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|X|
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|X
# -----
# X|X|O
#
# --------------------------------------------------
#
# Game ID: ad1df1af-9ff8-469e-ab80-572c0ae3cc22
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
# O|O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X| |
# -----
# O|O|X
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
# O|O|X
# -----
#  |O|
#
# Player 1 move
# Chaos Agent Activated
# X| |
# -----
# O|O|X
# -----
#  |O|
#
# Player 2 move
# Cyber move: kill_daemon_command
# X|O|
# -----
# O|O|X
# -----
#  |O|
#
# --------------------------------------------------
#
# Game ID: b5740fc8-f8a0-48fc-8ef2-f0e05c19b52e
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
# O|O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# X| |
# -----
# O|O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_daemon_command
# X| |
# -----
# O|O|O
# -----
#  | |
#
# --------------------------------------------------
#
# Game ID: be0e8aaf-00bf-4815-8450-381e5bea2319
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  |X|
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
# O|O|
# -----
#  |X|
#
# Player 1 move
# Cyber move: use_command
#  |X|
# -----
# O|O|X
# -----
#  |X|
#
# Player 2 move
# Cyber move: nop_command
# O|X|
# -----
# O|O|X
# -----
#  |X|
#
# Player 1 move
# Chaos Agent Activated
# O|X|
# -----
# O|O|X
# -----
#  |X|
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|X|
# -----
# O|O|X
# -----
# O|X|
#
# --------------------------------------------------
#
# Game ID: bf88fb49-5c43-4248-bdc8-7185e62a37af
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|
# -----
#  |X|
#
# Player 2 move
# Cyber move: nop_command
#  |X|
# -----
#  |O|O
# -----
#  |X|
#
# Player 1 move
# Cyber move: scan_command
#  |X|
# -----
#  |O|O
# -----
#  |X|X
#
# Player 2 move
# Cyber move: kill_daemon_command
#  |X|
# -----
# O|O|O
# -----
#  |X|X
#
# --------------------------------------------------
#
# Game ID: ce1897c6-adbc-4014-8f23-f77a4742c90e
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# X|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
#  |O|
# -----
# X| |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|
# -----
# X| |
#
# Player 1 move
# Cyber move: use_command
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 2 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X| |O
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|X|O
#
# --------------------------------------------------
#
# Game ID: d02e1c87-e649-4c18-bf46-d8685788601a
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |O
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  | |O
#
# Player 2 move
# Cyber move: kill_daemon_command
# O| |
# -----
#  |O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: dc65cd5d-30dd-40ff-8c35-10ce8a8df11a
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# O| |
# -----
#  |O|
# -----
#  | |X
#
# Player 2 move
# Cyber move: nop_command
# O| |O
# -----
#  |O|
# -----
#  | |X
#
# Player 1 move
# Chaos Agent Activated
# O|O|O
# -----
#  |O|
# -----
#  | |X
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|O|O
# -----
#  |O|
# -----
#  | |X
#
# --------------------------------------------------
#
# Game ID: e02114bf-dfc7-44e2-afa9-219ccca617ee
# Player 1 move
# Cyber move: scan_command
# X| |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# X| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: use_command
# X|X|
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
#  |O|
# -----
# X| |
#
# Player 2 move
# Cyber move: kill_process_command
# X|X|O
# -----
# O|O|
# -----
# X| |
#
# Player 1 move
# Cyber move: scan_command
# X|X|O
# -----
# O|O|X
# -----
# X| |
#
# Player 2 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X| |O
#
# Player 1 move
# Cyber move: nop_command
# X|X|O
# -----
# O|O|X
# -----
# X|X|O
#
# --------------------------------------------------
#
# Game ID: f0ca7f80-5473-4c9e-8db6-2ab39b1bcfdb
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 1 move
# Chaos Agent Activated
# O| |
# -----
#  |O|
# -----
#  | |
#
# Player 2 move
# Cyber move: kill_daemon_command
# O| |
# -----
#  |O|
# -----
#  | |O
#
# --------------------------------------------------
#
# Game ID: f846f134-abf7-4e4d-b392-d6abb4a829f2
# Player 1 move
# Chaos Agent Activated
#  | |
# -----
#  | |
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  | |
# -----
#  | |
#
# Player 1 move
# Cyber move: scan_command
# O| |
# -----
#  |X|
# -----
#  | |
#
# Player 2 move
# Cyber move: nop_command
# O| |
# -----
#  |X|
# -----
#  | |O
#
# Player 1 move
# Cyber move: use_command
# O|X|
# -----
#  |X|
# -----
#  | |O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|
# -----
#  |X|
# -----
#  |O|O
#
# Player 1 move
# Cyber move: use_command
# O|X|
# -----
#  |X|
# -----
# X|O|O
#
# Player 2 move
# Cyber move: kill_process_command
# O|X|O
# -----
#  |X|
# -----
# X|O|O
#
# Player 1 move
# Chaos Agent Activated
# O|X|O
# -----
#  |X|
# -----
# X|O|O
#
# Player 2 move
# Cyber move: kill_daemon_command
# O|X|O
# -----
#  |X|O
# -----
# X|O|O
#
# --------------------------------------------------
